# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imshow
from skimage.color import rgb2hsv, rgb2gray, rgb2yuv
from skimage import color, exposure, transform
from skimage.exposure import equalize_hist

# %%
name = '1000k'

# %%
input_image = cv2.imread(name + '.tif')

plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(input_image, cmap='gray');

input_fourier = np.fft.fftshift(np.fft.fft2(input_image))
plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(np.log(abs(input_fourier)), cmap='gray');
# Out:
# /tmp/ipykernel_8380/2887289592.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(abs(input_fourier)), cmap='gray');
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
result_image = cv2.imread('1000k_result.tif')

plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(result_image, cmap='gray');

result_fourier = np.fft.fftshift(np.fft.fft2(result_image))
plt.figure(num=None, figsize=(8, 6), dpi=80)
plt.imshow(np.log(abs(result_fourier)), cmap='gray');
# Out:
# /tmp/ipykernel_8380/1710237086.py:8: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(abs(result_fourier)), cmap='gray');
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #OpenCV

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

img = cv2.imread(name + ".tif",cv2.IMREAD_UNCHANGED)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
equ = cv2.equalizeHist(img) 

plt.imshow(cv2.cvtColor(equ, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
# Remove noise using a median filter
filtered_image = cv2.GaussianBlur(img, (7, 7), 0)

plt.imshow(cv2.cvtColor(filtered_image, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
# Create the sharpening kernel
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

# Sharpen the image
result_image = cv2.filter2D(img, -1, kernel)

plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
# as opencv loads in BGR format by default, we want to show it in RGB.
plt.show()

# %%
cv2.imwrite(name + '_result.tif', equ)
# Out:
# True
